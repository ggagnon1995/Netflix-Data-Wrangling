# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Lets use Netflix movie and show data across the world

# %%
raw_netflix_pop_data = pd.read_csv('all-weeks-countries.csv')
# Assign a copy of the data
netflix_popularity = raw_netflix_pop_data.copy()
netflix_popularity
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AR  2022-01-23    Films            1
# 1        Argentina           AR  2022-01-23    Films            2
# 2        Argentina           AR  2022-01-23    Films            3
# 3        Argentina           AR  2022-01-23    Films            4
# 4        Argentina           AR  2022-01-23    Films            5
# ...            ...          ...         ...      ...          ...
# 56395      Vietnam           VN  2021-07-04       TV            6
# 56396      Vietnam           VN  2021-07-04       TV            7
# 56397      Vietnam           VN  2021-07-04       TV            8
# 56398      Vietnam           VN  2021-07-04       TV            9
# 56399      Vietnam           VN  2021-07-04       TV           10
#
#                       show_title                    season_title  \
# 0      The Secret Life of Pets 2                             NaN
# 1            The Royal Treatment                             NaN
# 2                         Brazen                             NaN
# 3          The Clovehitch Killer                             NaN
# 4                  Don't Look Up                             NaN
# ...                          ...                             ...
# 56395                 Reply 1988            Reply 1988: Season 1
# 56396              Nevertheless,         Nevertheless,: Season 1
# 56397          Too Hot to Handle     Too Hot to Handle: Season 2
# 56398         Record of Ragnarok    Record of Ragnarok: Season 1
# 56399       Crash Landing on You  Crash Landing on You: Season 1
#
#        cumulative_weeks_in_top_10
# 0                               2
# 1                               1
# 2                               2
# 3                               2
# 4                               5
# ...                           ...
# 56395                           1
# 56396                           1
# 56397                           1
# 56398                           1
# 56399                           1
#
# [56400 rows x 8 columns]

# %%
# check the characteristics 
netflix_popularity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56400 entries, 0 to 56399
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   country_name                56400 non-null  object
#  1   country_iso2                56400 non-null  object
#  2   week                        56400 non-null  object
#  3   category                    56400 non-null  object
#  4   weekly_rank                 56400 non-null  int64
#  5   show_title                  56400 non-null  object
#  6   season_title                27912 non-null  object
#  7   cumulative_weeks_in_top_10  56400 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 3.4+ MB

# %%
# list column names 
netflix_popularity.columns.values
# Out:
# array(['country_name', 'country_iso2', 'week', 'category', 'weekly_rank',
#        'show_title', 'season_title', 'cumulative_weeks_in_top_10'],
#       dtype=object)

# %%
# drop 'country_iso2'
netflix_popularity = netflix_popularity.drop(['country_iso2'], axis = 1)

# %% [markdown]
# # Removing unwanted data

# %% [markdown]
# ### season_title has NaN, for practice we will remove these but won't alter the actual data

# %%
# season title has NaN, for practice we will remove these but don't alter the actual data
df_unwanted = netflix_popularity.copy()

# %%
df_unwanted = df_unwanted.dropna(axis = 0, how = 'any', inplace = False)
df_unwanted
# Out:
#       country_name        week category  weekly_rank               show_title  \
# 10       Argentina  2022-01-23       TV            1  Café con aroma de mujer
# 11       Argentina  2022-01-23       TV            2              El marginal
# 12       Argentina  2022-01-23       TV            3        The Queen of Flow
# 13       Argentina  2022-01-23       TV            4               Archive 81
# 14       Argentina  2022-01-23       TV            5        The Queen of Flow
# ...            ...         ...      ...          ...                      ...
# 56395      Vietnam  2021-07-04       TV            6               Reply 1988
# 56396      Vietnam  2021-07-04       TV            7            Nevertheless,
# 56397      Vietnam  2021-07-04       TV            8        Too Hot to Handle
# 56398      Vietnam  2021-07-04       TV            9       Record of Ragnarok
# 56399      Vietnam  2021-07-04       TV           10     Crash Landing on You
#
#                             season_title  cumulative_weeks_in_top_10
# 10     Café con aroma de mujer: Season 1                           4
# 11                 El marginal: Season 4                           1
# 12           The Queen of Flow: Season 2                          10
# 13                  Archive 81: Season 1                           1
# 14           The Queen of Flow: Season 1                          12
# ...                                  ...                         ...
# 56395               Reply 1988: Season 1                           1
# 56396            Nevertheless,: Season 1                           1
# 56397        Too Hot to Handle: Season 2                           1
# 56398       Record of Ragnarok: Season 1                           1
# 56399     Crash Landing on You: Season 1                           1
#
# [27912 rows x 7 columns]

# %% [markdown]
# ### season_title has colons and season numbers, suppose we don't want those included

# %% [markdown]
# #### remember data type is object, and we first want to convert it to a string before we can alter it

# %%
df_unwanted['season_title'] = df_unwanted['season_title'].convert_dtypes(convert_string=True)

# %%
# check to see it worked
df_unwanted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27912 entries, 10 to 56399
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   country_name                27912 non-null  object
#  1   week                        27912 non-null  object
#  2   category                    27912 non-null  object
#  3   weekly_rank                 27912 non-null  int64
#  4   show_title                  27912 non-null  object
#  5   season_title                27912 non-null  string
#  6   cumulative_weeks_in_top_10  27912 non-null  int64
# dtypes: int64(2), object(4), string(1)
# memory usage: 1.7+ MB

# %%
# first lets remove the colon and word season
df_unwanted['season_title'] = df_unwanted['season_title'].str.replace(': Season', '')
df_unwanted
# Out:
#       country_name        week category  weekly_rank               show_title  \
# 10       Argentina  2022-01-23       TV            1  Café con aroma de mujer
# 11       Argentina  2022-01-23       TV            2              El marginal
# 12       Argentina  2022-01-23       TV            3        The Queen of Flow
# 13       Argentina  2022-01-23       TV            4               Archive 81
# 14       Argentina  2022-01-23       TV            5        The Queen of Flow
# ...            ...         ...      ...          ...                      ...
# 56395      Vietnam  2021-07-04       TV            6               Reply 1988
# 56396      Vietnam  2021-07-04       TV            7            Nevertheless,
# 56397      Vietnam  2021-07-04       TV            8        Too Hot to Handle
# 56398      Vietnam  2021-07-04       TV            9       Record of Ragnarok
# 56399      Vietnam  2021-07-04       TV           10     Crash Landing on You
#
#                     season_title  cumulative_weeks_in_top_10
# 10     Café con aroma de mujer 1                           4
# 11                 El marginal 4                           1
# 12           The Queen of Flow 2                          10
# 13                  Archive 81 1                           1
# 14           The Queen of Flow 1                          12
# ...                          ...                         ...
# 56395               Reply 1988 1                           1
# 56396            Nevertheless, 1                           1
# 56397        Too Hot to Handle 2                           1
# 56398       Record of Ragnarok 1                           1
# 56399     Crash Landing on You 1                           1
#
# [27912 rows x 7 columns]

# %%
# now we don't want to remove numbers, since some of the titles contain numbers in the name
# we can slice off the last character 
df_unwanted['season_title'] = df_unwanted['season_title'].map(lambda x: str(x)[:-1])
df_unwanted
# Out:
#       country_name        week category  weekly_rank               show_title  \
# 10       Argentina  2022-01-23       TV            1  Café con aroma de mujer
# 11       Argentina  2022-01-23       TV            2              El marginal
# 12       Argentina  2022-01-23       TV            3        The Queen of Flow
# 13       Argentina  2022-01-23       TV            4               Archive 81
# 14       Argentina  2022-01-23       TV            5        The Queen of Flow
# ...            ...         ...      ...          ...                      ...
# 56395      Vietnam  2021-07-04       TV            6               Reply 1988
# 56396      Vietnam  2021-07-04       TV            7            Nevertheless,
# 56397      Vietnam  2021-07-04       TV            8        Too Hot to Handle
# 56398      Vietnam  2021-07-04       TV            9       Record of Ragnarok
# 56399      Vietnam  2021-07-04       TV           10     Crash Landing on You
#
#                    season_title  cumulative_weeks_in_top_10
# 10     Café con aroma de mujer                            4
# 11                 El marginal                            1
# 12           The Queen of Flow                           10
# 13                  Archive 81                            1
# 14           The Queen of Flow                           12
# ...                         ...                         ...
# 56395               Reply 1988                            1
# 56396            Nevertheless,                            1
# 56397        Too Hot to Handle                            1
# 56398       Record of Ragnarok                            1
# 56399     Crash Landing on You                            1
#
# [27912 rows x 7 columns]

# %% [markdown]
# # Lets go back to the initial data set and work towards the end goal

# %% [markdown]
# ## We want to compare countries based on their top shows and movies. Once the data is processed, the goal is to create a visualization that shows which countries have similar taste in shows and movies in Tableau.

# %% [markdown]
# ### First I will alter the date so it is no longer an object

# %%
netflix_popularity['week'] = pd.to_datetime(netflix_popularity['week'])

# %%
# check to see that it worked 
netflix_popularity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56400 entries, 0 to 56399
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   country_name                56400 non-null  object
#  1   week                        56400 non-null  datetime64[ns]
#  2   category                    56400 non-null  object
#  3   weekly_rank                 56400 non-null  int64
#  4   show_title                  56400 non-null  object
#  5   season_title                27912 non-null  object
#  6   cumulative_weeks_in_top_10  56400 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 3.0+ MB

# %%
# Unique weeks 
len(pd.unique(netflix_popularity['week']))
# Out:
# 30

# %%
# I don't care for the season_title column
netflix_popularity = netflix_popularity.drop(['season_title'], axis = 1)

# %%
netflix_popularity
# Out:
#       country_name       week category  weekly_rank  \
# 0        Argentina 2022-01-23    Films            1
# 1        Argentina 2022-01-23    Films            2
# 2        Argentina 2022-01-23    Films            3
# 3        Argentina 2022-01-23    Films            4
# 4        Argentina 2022-01-23    Films            5
# ...            ...        ...      ...          ...
# 56395      Vietnam 2021-07-04       TV            6
# 56396      Vietnam 2021-07-04       TV            7
# 56397      Vietnam 2021-07-04       TV            8
# 56398      Vietnam 2021-07-04       TV            9
# 56399      Vietnam 2021-07-04       TV           10
#
#                       show_title  cumulative_weeks_in_top_10
# 0      The Secret Life of Pets 2                           2
# 1            The Royal Treatment                           1
# 2                         Brazen                           2
# 3          The Clovehitch Killer                           2
# 4                  Don't Look Up                           5
# ...                          ...                         ...
# 56395                 Reply 1988                           1
# 56396              Nevertheless,                           1
# 56397          Too Hot to Handle                           1
# 56398         Record of Ragnarok                           1
# 56399       Crash Landing on You                           1
#
# [56400 rows x 6 columns]

# %%
# lets take a look at the cumulative_weeks_in_top_10 values
pd.unique(netflix_popularity['cumulative_weeks_in_top_10'])
# Out:
# array([ 2,  1,  5,  4, 10, 12, 30,  3,  9, 11, 29,  8, 28,  7, 27,  6, 26,
#        21, 25, 20, 24, 19, 23, 18, 22, 17, 16, 15, 14, 13])

# %% [markdown]
# ## Lets take a look at shows only, we want to see each countries highest cumulative top 10 show

# %%
# lets split the data into shows only
df_shows = netflix_popularity.copy()
df_shows = df_shows.drop(df_shows[df_shows.category == 'Films'].index)
df_shows
# Out:
#       country_name       week category  weekly_rank               show_title  \
# 10       Argentina 2022-01-23       TV            1  Café con aroma de mujer
# 11       Argentina 2022-01-23       TV            2              El marginal
# 12       Argentina 2022-01-23       TV            3        The Queen of Flow
# 13       Argentina 2022-01-23       TV            4               Archive 81
# 14       Argentina 2022-01-23       TV            5        The Queen of Flow
# ...            ...        ...      ...          ...                      ...
# 56395      Vietnam 2021-07-04       TV            6               Reply 1988
# 56396      Vietnam 2021-07-04       TV            7            Nevertheless,
# 56397      Vietnam 2021-07-04       TV            8        Too Hot to Handle
# 56398      Vietnam 2021-07-04       TV            9       Record of Ragnarok
# 56399      Vietnam 2021-07-04       TV           10     Crash Landing on You
#
#        cumulative_weeks_in_top_10
# 10                              4
# 11                              1
# 12                             10
# 13                              1
# 14                             12
# ...                           ...
# 56395                           1
# 56396                           1
# 56397                           1
# 56398                           1
# 56399                           1
#
# [28200 rows x 6 columns]

# %%
# lets group by country and keep only the highest cumulative weeks in top 10
df_shows = df_shows.loc[df_shows.groupby('country_name')['cumulative_weeks_in_top_10'].idxmax()]
df_shows
# Out:
#          country_name       week category  weekly_rank             show_title  \
# 17          Argentina 2022-01-23       TV            8    Pasión de Gavilanes
# 719         Australia 2021-12-19       TV           10                   Maid
# 1359          Austria 2021-12-05       TV           10             Squid Game
# 1816          Bahamas 2022-01-23       TV            7  SpongeBob SquarePants
# 2479          Bahrain 2022-01-02       TV           10             Squid Game
# ...               ...        ...      ...          ...                    ...
# 53596  United Kingdom 2021-11-21       TV            7             Squid Game
# 54098   United States 2021-12-26       TV            9              CoComelon
# 54615         Uruguay 2022-01-23       TV            6      The Queen of Flow
# 55212       Venezuela 2022-01-23       TV            3   Yo soy Betty, la fea
# 55818         Vietnam 2022-01-23       TV            9             Reply 1988
#
#        cumulative_weeks_in_top_10
# 17                             30
# 719                            12
# 1359                           12
# 1816                           15
# 2479                           16
# ...                           ...
# 53596                          10
# 54098                          16
# 54615                          12
# 55212                          30
# 55818                          24
#
# [94 rows x 6 columns]

# %%
# check for duplicates 
duplicate_shows = df_shows.duplicated(subset=['country_name']).any()
duplicate_shows
# Out:
# False

# %%
# drop unwanted columns 
df_shows = df_shows.drop(['category', 'week', 'weekly_rank'], axis = 1)
df_shows
# Out:
#          country_name             show_title  cumulative_weeks_in_top_10
# 17          Argentina    Pasión de Gavilanes                          30
# 719         Australia                   Maid                          12
# 1359          Austria             Squid Game                          12
# 1816          Bahamas  SpongeBob SquarePants                          15
# 2479          Bahrain             Squid Game                          16
# ...               ...                    ...                         ...
# 53596  United Kingdom             Squid Game                          10
# 54098   United States              CoComelon                          16
# 54615         Uruguay      The Queen of Flow                          12
# 55212       Venezuela   Yo soy Betty, la fea                          30
# 55818         Vietnam             Reply 1988                          24
#
# [94 rows x 3 columns]

# %%
# now this data is useable, lets save it 
df_shows.to_csv('Top_Cumulative_Shows.csv', index=False)

# %% [markdown]
# ## Lets take a look at movies only, we want to see each countries highest cumulative top 10 movie

# %%
df_movies = netflix_popularity.copy()
df_movies = df_movies.drop(df_movies[df_movies.category == 'TV'].index)
df_movies
# Out:
#       country_name       week category  weekly_rank  \
# 0        Argentina 2022-01-23    Films            1
# 1        Argentina 2022-01-23    Films            2
# 2        Argentina 2022-01-23    Films            3
# 3        Argentina 2022-01-23    Films            4
# 4        Argentina 2022-01-23    Films            5
# ...            ...        ...      ...          ...
# 56385      Vietnam 2021-07-04    Films            6
# 56386      Vietnam 2021-07-04    Films            7
# 56387      Vietnam 2021-07-04    Films            8
# 56388      Vietnam 2021-07-04    Films            9
# 56389      Vietnam 2021-07-04    Films           10
#
#                        show_title  cumulative_weeks_in_top_10
# 0       The Secret Life of Pets 2                           2
# 1             The Royal Treatment                           1
# 2                          Brazen                           2
# 3           The Clovehitch Killer                           2
# 4                   Don't Look Up                           5
# ...                           ...                         ...
# 56385            Camellia Sisters                           1
# 56386                   12 Strong                           1
# 56387                      Glitch                           1
# 56388   Pokémon Detective Pikachu                           1
# 56389  Rurouni Kenshin: The Final                           1
#
# [28200 rows x 6 columns]

# %%
# lets group by country and keep only the highest cumulative weeks in top 10
df_movies = df_movies.loc[df_movies.groupby('country_name')['cumulative_weeks_in_top_10'].idxmax()]
df_movies
# Out:
#          country_name       week category  weekly_rank  \
# 4           Argentina 2022-01-23    Films            5
# 625         Australia 2022-01-16    Films            6
# 1267          Austria 2022-01-02    Films            8
# 1829          Bahamas 2022-01-16    Films           10
# 2468          Bahrain 2022-01-02    Films            9
# ...               ...        ...      ...          ...
# 53469  United Kingdom 2022-01-02    Films           10
# 54328   United States 2021-10-03    Films            9
# 54604         Uruguay 2022-01-23    Films            5
# 55208       Venezuela 2022-01-23    Films            9
# 55804         Vietnam 2022-01-23    Films            5
#
#                    show_title  cumulative_weeks_in_top_10
# 4               Don't Look Up                           5
# 625       Back to the Outback                           6
# 1267               Red Notice                           7
# 1829   A Madea Family Funeral                           6
# 2468               Red Notice                           8
# ...                       ...                         ...
# 53469              Red Notice                           6
# 54328                    Vivo                           9
# 54604           Don't Look Up                           5
# 55208              Red Notice                          11
# 55804              Red Notice                          11
#
# [94 rows x 6 columns]

# %%
# no need to check for duplicates again, 94 rows implies there are none 
# drop unwanted columns 
df_movies = df_movies.drop(['category', 'week', 'weekly_rank'], axis = 1)
df_movies
# Out:
#          country_name              show_title  cumulative_weeks_in_top_10
# 4           Argentina           Don't Look Up                           5
# 625         Australia     Back to the Outback                           6
# 1267          Austria              Red Notice                           7
# 1829          Bahamas  A Madea Family Funeral                           6
# 2468          Bahrain              Red Notice                           8
# ...               ...                     ...                         ...
# 53469  United Kingdom              Red Notice                           6
# 54328   United States                    Vivo                           9
# 54604         Uruguay           Don't Look Up                           5
# 55208       Venezuela              Red Notice                          11
# 55804         Vietnam              Red Notice                          11
#
# [94 rows x 3 columns]

# %%
# now this data is useable, lets save it 
df_movies.to_csv('Top_Cumulative_Movies.csv', index=False)
